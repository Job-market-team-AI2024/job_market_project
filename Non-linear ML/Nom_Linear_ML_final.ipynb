# %%
import pandas as pd
import numpy as np
import os
import requests
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.feature_extraction.text import CountVectorizer
from catboost import CatBoostRegressor
from xgboost import XGBRegressor
import matplotlib.pyplot as plt
import seaborn as sns

# %%
URL_BASE = 'https://media.githubusercontent.com/media/Job-market-team-AI2024/job_market_project/refs/heads/main/data/'
def read_database(file_name):
    return pd.read_csv(os.path.join(URL_BASE, file_name))

# %%
df = read_database('IT_vacancies.csv')

# %% [markdown]
# ### Добавление региона и страны вакансии

# %%
def area_transform(entry):
    areas_dict = {}
    areas_dict[entry['id']] = {'name': entry['name'], 'parent_id': entry['parent_id']}
    for area in entry['areas']:
        areas_dict.update(area_transform(area))
    return areas_dict

def area_region(area_id, areas_dict):
    if areas_dict[area_id]['parent_id'] is None or areas_dict[areas_dict[area_id]['parent_id']]['parent_id'] is None:
        return areas_dict[area_id]['name']
    else:
        return areas_dict[areas_dict[area_id]['parent_id']]['name']

def area_country(area_id, areas_dict):
    while areas_dict[area_id]['parent_id'] is not None:
        area_id = areas_dict[area_id]['parent_id']
    return areas_dict[area_id]['name']

# %%
areas = requests.get('https://api.hh.ru/areas').json()

areas_dict = {}

for area in areas:
    areas_dict.update(area_transform(area))

# %%
df['region_name'] = df['area_id'].apply(lambda x: area_region(str(x), areas_dict))
df['country_name'] = df['area_id'].apply(lambda x: area_country(str(x), areas_dict))

# %% [markdown]
# ### Добавление категорей, ролей и грейдов

# %%
categories = {
    'field': [
        ("product", ['product', 'продуктовый', 'продакт', 'продукта']),
        ("project", ['project', 'проектов', 'проектный', 'проекта']),
        ("data", ['data', 'дата', 'данных']),
        ("bi", ['bi', 'би', 'визуализация']),
        ("business", ['business', 'бизнес']),
        ("system", ['system', 'системный']),
        ("technical", ['qa', 'по', 'программного обеспечения', '1C', '1С', 'технический', 'technical', 'информационной безопасности']),
        ("support", ['поддержк', 'support']),
        ("design", ['graphic', 'web', 'графический', 'веб'])
    ],
    'role': [
        ("developer", ['developer', 'разработчик', 'программист', 'архитектор', 'architect', 'devops', 'mlops', 'разработка', 'разработку', 'программирование']),
        ("scientist", ['scientist', 'science', 'саенс']),
        ("analyst", ['analyst', 'analysis', 'analytics', 'аналитик']),
        ("consultant", ['consultant', 'консультант', 'технолог']),
        ("manager", ['manager', 'lead', 'owner', 'менеджер', 'лид', 'руководитель', 'руководителя', 'оунэр', 'оунер', 'coordinator', 'координатор', 'директор', 'director', 'владелец', 'начальник', 'chief']),
        ("tester", ['тестировщик', 'qa', 'автоматизатор тестирования', 'tester']),
        ("engineer", ['engineer', 'инженер']),
        ("specialist", ['specialist', 'operator', 'support', 'специалист', 'оператор', 'писатель', 'мастер', 'эксперт', 'поддержки', 'поддержка']),
        ("designer", ['design', 'designer', 'дизайн', 'дизайнер', 'artist', 'художник']),
        ("admin", ['администратор'])
    ],
    'grade': [
        ("intern", ['intern', 'стажер']),
        ("junior", ['junior', 'младший']),
        ("middle", ['middle', 'ведущий']),
        ("senior", ['senior', 'старший']),
        ("lead", ['lead', 'руководитель', 'начальник'])
    ]
}

# Функция для поиска категорий
def find_categories(name, categories):
    return [category for category, elements in categories if any(el.lower() in name.lower() for el in elements)]

# Применение функции к DataFrame
for category_type, category_list in categories.items():
    df[f'{category_type}s'] = df['name'].apply(lambda x: find_categories(x, category_list))
    df[category_type] = df[f'{category_type}s'].apply(lambda x: ' '.join(x))

# %% [markdown]
# ### Зарплата

# %%
df['salary'] = df[['salary_from', 'salary_to']].mean(axis=1)

# %% [markdown]
# ### Ограничения на страну + удаление выбросов в зарплатах

# %%
df = df[df['country_name'] == 'Россия']

df = df[~df['salary'].isnull()]
df = df[df['salary_currency'] == 'RUR']

df = df[df['salary'] > np.quantile(df['salary'],0.005)]
df = df[df['salary'] < np.quantile(df['salary'],0.995)]

# %% [markdown]
# ### Разделим данные на целевую переменную и признаки

# %%
X = df.drop(columns=['salary_from', 'salary_to', 'salary'])
y = df['salary']

# %% [markdown]
# ### Удаление пропусков

# %%
X['key_skills'] = X['key_skills'].fillna('')
X['accredited_it_employer'] = X['accredited_it_employer'].fillna(False)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_39180\1094086166.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X['accredited_it_employer'] = X['accredited_it_employer'].fillna(False)

# %% [markdown]
# ### Разделение на трейн и тест

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %% [markdown]
# ### Выделение групп признаков

# %%
cat_features = ['area_name', 'region_name', 'experience', 'employer_name', 'schedule', 'employment', 'field', 'role', 'grade',
                'professional_roles_name', 'accredited_it_employer', 'has_test', 'billing_type', 'allow_messages',
                'accept_temporary', 'response_letter_required', 'accept_incomplete_resumes'
               ]

num_features = ['count_key_skills']

# %% [markdown]
# ### Метрики качества

# %%
def MAPE(y_true, y_pred):
  """
  Compute Mean Absolute Percentage Error (MAPE)

  Input:
  y_true (array-like): Actual target values
  y_pred (array-like): Predicted target values

  Returns:
  float: MAPE as a percentage
  """
  y_true = np.array(y_true)
  y_pred = np.array(y_pred)

  ### избегаем нули, чтобы корректно отработало
  non_zero_mask = y_true != 0
  percentage_errors = np.abs((y_true[non_zero_mask] - y_pred[non_zero_mask]) / y_true[non_zero_mask])
  return np.mean(percentage_errors) * 100

# %%
def share_within_indifference_interval(y_true, y_pred, percentage):
  """
  Share of predicted targets within percentage interval of true targets

  Input:
  y_true (array-like): Actual target values
  y_pred (array-like): Predicted target values

  Returns:
  float: Share as percentage
  """
  x = (y_pred - y_true) / y_true
  return ((x <= percentage / 100) & (x >= -percentage / 100)).mean() * 100

# %% [markdown]
# ### Преобразование признаков
# - Категориальные: Без изменений (Catboost), OneHotEncoder для остальных моделей
# - Числовые (количество указанных навыков в вакансии): Стандартизация
# - Текстовые (название вакансии и ключевые навыки): CountVectorizer, топ-20 самых популярных слов

# %%
column_transform_ctb = ColumnTransformer(
    transformers=[
        ('cat', 'passthrough', cat_features),
        ('num', StandardScaler(), num_features),
        ('name', CountVectorizer(max_features=20), 'name'),
        ('key_skills', CountVectorizer(max_features=20), 'key_skills')
    ],
    remainder='drop'
)

column_transform = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(drop='first', handle_unknown='ignore'), cat_features),
        ('num', StandardScaler(), num_features),
        ('name', CountVectorizer(max_features=20), 'name'),
        ('key_skills', CountVectorizer(max_features=20), 'key_skills')
    ], remainder='drop'
)

# %% [markdown]
# ### CatBoost

# %%
X_train_ctb = column_transform_ctb.fit_transform(X_train)
X_test_ctb = column_transform_ctb.transform(X_test)

X_train_ctb = pd.DataFrame(X_train, columns=cat_features + list(range(X_train.shape[1] - len(cat_features))))
X_test_ctb = pd.DataFrame(X_test, columns=cat_features + list(range(X_test.shape[1] - len(cat_features))))

# %%
ctb = CatBoostRegressor(cat_features=cat_features, loss_function='MAPE')
ctb.fit(X_train_ctb, np.log(y_train))
# Out:
# 0:	learn: 0.0450643	total: 114ms	remaining: 1m 54s
# 1:	learn: 0.0442450	total: 170ms	remaining: 1m 24s
# 2:	learn: 0.0434430	total: 219ms	remaining: 1m 12s
# 3:	learn: 0.0426760	total: 268ms	remaining: 1m 6s
# 4:	learn: 0.0419747	total: 296ms	remaining: 58.9s
# 5:	learn: 0.0412917	total: 336ms	remaining: 55.7s
# 6:	learn: 0.0406353	total: 373ms	remaining: 53s
# 7:	learn: 0.0400061	total: 423ms	remaining: 52.4s
# 8:	learn: 0.0393940	total: 469ms	remaining: 51.6s
# 9:	learn: 0.0388194	total: 505ms	remaining: 50s
# 10:	learn: 0.0382511	total: 562ms	remaining: 50.5s
# 11:	learn: 0.0377191	total: 606ms	remaining: 49.9s
# 12:	learn: 0.0372195	total: 641ms	remaining: 48.7s
# 13:	learn: 0.0367303	total: 683ms	remaining: 48.1s
# 14:	learn: 0.0362465	total: 731ms	remaining: 48s
# 15:	learn: 0.0357867	total: 759ms	remaining: 46.6s
# 16:	learn: 0.0353424	total: 802ms	remaining: 46.4s
# 17:	learn: 0.0349117	total: 838ms	remaining: 45.7s
# 18:	learn: 0.0345019	total: 883ms	remaining: 45.6s
# 19:	learn: 0.0341167	total: 930ms	remaining: 45.6s
# 20:	learn: 0.0337416	total: 968ms	remaining: 45.1s
# 21:	learn: 0.0333913	total: 1.01s	remaining: 45.1s
# 22:	learn: 0.0330781	total: 1.06s	remaining: 45.1s
# 23:	learn: 0.0327611	total: 1.1s	remaining: 44.8s
# 24:	learn: 0.0324578	total: 1.15s	remaining: 44.9s
# 25:	learn: 0.0321535	total: 1.2s	remaining: 45s
# 26:	learn: 0.0318753	total: 1.25s	remaining: 45s
# 27:	learn: 0.0316057	total: 1.3s	remaining: 45s
# 28:	learn: 0.0313448	total: 1.33s	remaining: 44.5s
# 29:	learn: 0.0310947	total: 1.36s	remaining: 44.2s
# 30:	learn: 0.0308633	total: 1.41s	remaining: 44s
# 31:	learn: 0.0306259	total: 1.46s	remaining: 44.1s
# 32:	learn: 0.0303847	total: 1.5s	remaining: 44s
# 33:	learn: 0.0301786	total: 1.55s	remaining: 44.1s
# 34:	learn: 0.0299856	total: 1.59s	remaining: 43.8s
# 35:	learn: 0.0298069	total: 1.64s	remaining: 43.8s
# 36:	learn: 0.0296293	total: 1.68s	remaining: 43.8s
# 37:	learn: 0.0294455	total: 1.72s	remaining: 43.6s
# 38:	learn: 0.0292856	total: 1.77s	remaining: 43.6s
# 39:	learn: 0.0291184	total: 1.81s	remaining: 43.5s
# 40:	learn: 0.0289729	total: 1.86s	remaining: 43.5s
# 371:	learn: 0.0220972	total: 17.5s	remaining: 29.5s
# 372:	learn: 0.0220951	total: 17.5s	remaining: 29.5s
# 373:	learn: 0.0220935	total: 17.6s	remaining: 29.4s
# 374:	learn: 0.0220895	total: 17.6s	remaining: 29.4s
# 375:	learn: 0.0220878	total: 17.7s	remaining: 29.4s
# 376:	learn: 0.0220837	total: 17.7s	remaining: 29.3s
# 377:	learn: 0.0220798	total: 17.8s	remaining: 29.3s
# 378:	learn: 0.0220775	total: 17.8s	remaining: 29.2s
# 379:	learn: 0.0220744	total: 17.9s	remaining: 29.2s
# 380:	learn: 0.0220698	total: 17.9s	remaining: 29.1s
# 381:	learn: 0.0220669	total: 18s	remaining: 29.1s
# 382:	learn: 0.0220612	total: 18s	remaining: 29s
# 383:	learn: 0.0220593	total: 18.1s	remaining: 29s
# 384:	learn: 0.0220555	total: 18.1s	remaining: 28.9s
# 385:	learn: 0.0220514	total: 18.1s	remaining: 28.9s
# 386:	learn: 0.0220481	total: 18.2s	remaining: 28.8s
# 387:	learn: 0.0220452	total: 18.2s	remaining: 28.8s
# 388:	learn: 0.0220404	total: 18.3s	remaining: 28.7s
# 389:	learn: 0.0220379	total: 18.3s	remaining: 28.7s
# 390:	learn: 0.0220356	total: 18.4s	remaining: 28.7s
# 391:	learn: 0.0220316	total: 18.5s	remaining: 28.6s
# 392:	learn: 0.0220302	total: 18.5s	remaining: 28.6s
# 393:	learn: 0.0220271	total: 18.6s	remaining: 28.6s
# 394:	learn: 0.0220212	total: 18.7s	remaining: 28.6s
# 395:	learn: 0.0220175	total: 18.8s	remaining: 28.6s
# 396:	learn: 0.0220153	total: 18.9s	remaining: 28.6s
# 397:	learn: 0.0220136	total: 18.9s	remaining: 28.6s
# 398:	learn: 0.0220092	total: 19s	remaining: 28.6s
# 399:	learn: 0.0220078	total: 19.1s	remaining: 28.7s
# 400:	learn: 0.0219976	total: 19.2s	remaining: 28.7s
# 401:	learn: 0.0219951	total: 19.3s	remaining: 28.7s
# 402:	learn: 0.0219917	total: 19.4s	remaining: 28.7s
# 403:	learn: 0.0219882	total: 19.4s	remaining: 28.7s
# 404:	learn: 0.0219847	total: 19.5s	remaining: 28.7s
# 405:	learn: 0.0219817	total: 19.6s	remaining: 28.6s
# 406:	learn: 0.0219798	total: 19.6s	remaining: 28.6s
# 407:	learn: 0.0219728	total: 19.7s	remaining: 28.6s
# 408:	learn: 0.0219704	total: 19.8s	remaining: 28.7s
# 409:	learn: 0.0219679	total: 19.9s	remaining: 28.7s
# 410:	learn: 0.0219668	total: 20s	remaining: 28.7s
# 411:	learn: 0.0219622	total: 20.1s	remaining: 28.7s
# 412:	learn: 0.0219560	total: 20.2s	remaining: 28.8s
# 413:	learn: 0.0219506	total: 20.3s	remaining: 28.8s
# 414:	learn: 0.0219470	total: 20.4s	remaining: 28.8s
# 415:	learn: 0.0219376	total: 20.5s	remaining: 28.8s
# 416:	learn: 0.0219312	total: 20.6s	remaining: 28.8s
# 417:	learn: 0.0219269	total: 20.7s	remaining: 28.8s
# 560:	learn: 0.0214751	total: 28.6s	remaining: 22.4s
# 561:	learn: 0.0214735	total: 28.6s	remaining: 22.3s
# 562:	learn: 0.0214696	total: 28.7s	remaining: 22.2s
# 563:	learn: 0.0214672	total: 28.7s	remaining: 22.2s
# 564:	learn: 0.0214654	total: 28.7s	remaining: 22.1s
# 565:	learn: 0.0214642	total: 28.8s	remaining: 22.1s
# 566:	learn: 0.0214616	total: 28.8s	remaining: 22s
# 567:	learn: 0.0214580	total: 28.9s	remaining: 22s
# 568:	learn: 0.0214558	total: 28.9s	remaining: 21.9s
# 569:	learn: 0.0214517	total: 29s	remaining: 21.9s
# 570:	learn: 0.0214484	total: 29s	remaining: 21.8s
# 571:	learn: 0.0214434	total: 29.1s	remaining: 21.8s
# 572:	learn: 0.0214402	total: 29.1s	remaining: 21.7s
# 573:	learn: 0.0214375	total: 29.2s	remaining: 21.7s
# 574:	learn: 0.0214355	total: 29.2s	remaining: 21.6s
# 575:	learn: 0.0214316	total: 29.3s	remaining: 21.6s
# 576:	learn: 0.0214273	total: 29.3s	remaining: 21.5s
# 577:	learn: 0.0214238	total: 29.4s	remaining: 21.5s
# 578:	learn: 0.0214218	total: 29.4s	remaining: 21.4s
# 579:	learn: 0.0214186	total: 29.5s	remaining: 21.4s
# 580:	learn: 0.0214163	total: 29.5s	remaining: 21.3s
# 581:	learn: 0.0214126	total: 29.6s	remaining: 21.3s
# 582:	learn: 0.0214109	total: 29.6s	remaining: 21.2s
# 583:	learn: 0.0214094	total: 29.7s	remaining: 21.1s
# 584:	learn: 0.0214080	total: 29.7s	remaining: 21.1s
# 585:	learn: 0.0214039	total: 29.8s	remaining: 21s
# 586:	learn: 0.0214028	total: 29.8s	remaining: 21s
# 587:	learn: 0.0213995	total: 29.9s	remaining: 20.9s
# 588:	learn: 0.0213975	total: 29.9s	remaining: 20.9s
# 589:	learn: 0.0213935	total: 30s	remaining: 20.8s
# 590:	learn: 0.0213915	total: 30s	remaining: 20.8s
# 591:	learn: 0.0213894	total: 30.1s	remaining: 20.7s
# 592:	learn: 0.0213871	total: 30.1s	remaining: 20.7s
# 593:	learn: 0.0213841	total: 30.2s	remaining: 20.6s
# 594:	learn: 0.0213810	total: 30.2s	remaining: 20.6s
# 595:	learn: 0.0213800	total: 30.2s	remaining: 20.5s
# 596:	learn: 0.0213782	total: 30.3s	remaining: 20.4s
# 597:	learn: 0.0213731	total: 30.3s	remaining: 20.4s
# 598:	learn: 0.0213703	total: 30.4s	remaining: 20.3s
# 599:	learn: 0.0213679	total: 30.4s	remaining: 20.3s
# 600:	learn: 0.0213637	total: 30.5s	remaining: 20.2s
# 601:	learn: 0.0213624	total: 30.5s	remaining: 20.2s
# 602:	learn: 0.0213602	total: 30.5s	remaining: 20.1s
# 603:	learn: 0.0213594	total: 30.6s	remaining: 20.1s
# 604:	learn: 0.0213566	total: 30.6s	remaining: 20s
# 605:	learn: 0.0213528	total: 30.7s	remaining: 19.9s
# 606:	learn: 0.0213518	total: 30.7s	remaining: 19.9s
# 654:	learn: 0.0212378	total: 34.1s	remaining: 18s
# 655:	learn: 0.0212353	total: 34.2s	remaining: 17.9s
# 656:	learn: 0.0212344	total: 34.2s	remaining: 17.9s
# 657:	learn: 0.0212310	total: 34.3s	remaining: 17.8s
# 658:	learn: 0.0212300	total: 34.4s	remaining: 17.8s
# 659:	learn: 0.0212286	total: 34.4s	remaining: 17.7s
# 660:	learn: 0.0212252	total: 34.5s	remaining: 17.7s
# 661:	learn: 0.0212234	total: 34.5s	remaining: 17.6s
# 662:	learn: 0.0212208	total: 34.5s	remaining: 17.6s
# 663:	learn: 0.0212175	total: 34.6s	remaining: 17.5s
# 664:	learn: 0.0212147	total: 34.6s	remaining: 17.4s
# 665:	learn: 0.0212132	total: 34.7s	remaining: 17.4s
# 666:	learn: 0.0212101	total: 34.7s	remaining: 17.3s
# 667:	learn: 0.0212082	total: 34.7s	remaining: 17.3s
# 668:	learn: 0.0212066	total: 34.8s	remaining: 17.2s
# 669:	learn: 0.0212041	total: 34.8s	remaining: 17.2s
# 670:	learn: 0.0212025	total: 34.9s	remaining: 17.1s
# 671:	learn: 0.0212009	total: 34.9s	remaining: 17.1s
# 672:	learn: 0.0211976	total: 35s	remaining: 17s
# 673:	learn: 0.0211953	total: 35s	remaining: 16.9s
# 674:	learn: 0.0211926	total: 35.1s	remaining: 16.9s
# 675:	learn: 0.0211900	total: 35.1s	remaining: 16.8s
# 676:	learn: 0.0211853	total: 35.2s	remaining: 16.8s
# 677:	learn: 0.0211839	total: 35.2s	remaining: 16.7s
# 678:	learn: 0.0211821	total: 35.3s	remaining: 16.7s
# 679:	learn: 0.0211789	total: 35.3s	remaining: 16.6s
# 680:	learn: 0.0211771	total: 35.4s	remaining: 16.6s
# 681:	learn: 0.0211752	total: 35.4s	remaining: 16.5s
# 682:	learn: 0.0211734	total: 35.5s	remaining: 16.5s
# 683:	learn: 0.0211713	total: 35.5s	remaining: 16.4s
# 684:	learn: 0.0211695	total: 35.5s	remaining: 16.3s
# 685:	learn: 0.0211673	total: 35.6s	remaining: 16.3s
# 686:	learn: 0.0211667	total: 35.6s	remaining: 16.2s
# 687:	learn: 0.0211646	total: 35.7s	remaining: 16.2s
# 688:	learn: 0.0211625	total: 35.7s	remaining: 16.1s
# 689:	learn: 0.0211610	total: 35.8s	remaining: 16.1s
# 690:	learn: 0.0211580	total: 35.8s	remaining: 16s
# 691:	learn: 0.0211546	total: 35.9s	remaining: 16s
# 692:	learn: 0.0211524	total: 35.9s	remaining: 15.9s
# 693:	learn: 0.0211497	total: 35.9s	remaining: 15.8s
# 694:	learn: 0.0211482	total: 36s	remaining: 15.8s
# 695:	learn: 0.0211451	total: 36s	remaining: 15.7s
# 696:	learn: 0.0211434	total: 36.1s	remaining: 15.7s
# 697:	learn: 0.0211408	total: 36.1s	remaining: 15.6s
# 698:	learn: 0.0211375	total: 36.2s	remaining: 15.6s
# 699:	learn: 0.0211366	total: 36.2s	remaining: 15.5s
# 700:	learn: 0.0211355	total: 36.3s	remaining: 15.5s
# 701:	learn: 0.0211330	total: 36.3s	remaining: 15.4s
# 749:	learn: 0.0210293	total: 38.6s	remaining: 12.9s
# 750:	learn: 0.0210277	total: 38.7s	remaining: 12.8s
# 751:	learn: 0.0210252	total: 38.7s	remaining: 12.8s
# 752:	learn: 0.0210238	total: 38.8s	remaining: 12.7s
# 753:	learn: 0.0210224	total: 38.8s	remaining: 12.7s
# 754:	learn: 0.0210207	total: 38.8s	remaining: 12.6s
# 755:	learn: 0.0210176	total: 38.9s	remaining: 12.6s
# 756:	learn: 0.0210158	total: 38.9s	remaining: 12.5s
# 757:	learn: 0.0210136	total: 39s	remaining: 12.4s
# 758:	learn: 0.0210111	total: 39s	remaining: 12.4s
# 759:	learn: 0.0210079	total: 39.1s	remaining: 12.3s
# 760:	learn: 0.0210065	total: 39.1s	remaining: 12.3s
# 761:	learn: 0.0210052	total: 39.2s	remaining: 12.2s
# 762:	learn: 0.0210037	total: 39.2s	remaining: 12.2s
# 763:	learn: 0.0210010	total: 39.3s	remaining: 12.1s
# 764:	learn: 0.0209990	total: 39.3s	remaining: 12.1s
# 765:	learn: 0.0209967	total: 39.4s	remaining: 12s
# 766:	learn: 0.0209943	total: 39.4s	remaining: 12s
# 767:	learn: 0.0209902	total: 39.4s	remaining: 11.9s
# 768:	learn: 0.0209872	total: 39.5s	remaining: 11.9s
# 769:	learn: 0.0209857	total: 39.5s	remaining: 11.8s
# 770:	learn: 0.0209834	total: 39.6s	remaining: 11.8s
# 771:	learn: 0.0209822	total: 39.6s	remaining: 11.7s
# 772:	learn: 0.0209810	total: 39.7s	remaining: 11.7s
# 773:	learn: 0.0209790	total: 39.7s	remaining: 11.6s
# 774:	learn: 0.0209772	total: 39.8s	remaining: 11.5s
# 775:	learn: 0.0209758	total: 39.8s	remaining: 11.5s
# 776:	learn: 0.0209732	total: 39.8s	remaining: 11.4s
# 777:	learn: 0.0209700	total: 39.9s	remaining: 11.4s
# 778:	learn: 0.0209676	total: 40s	remaining: 11.3s
# 779:	learn: 0.0209662	total: 40s	remaining: 11.3s
# 780:	learn: 0.0209641	total: 40s	remaining: 11.2s
# 781:	learn: 0.0209626	total: 40.1s	remaining: 11.2s
# 782:	learn: 0.0209614	total: 40.1s	remaining: 11.1s
# 783:	learn: 0.0209599	total: 40.2s	remaining: 11.1s
# 784:	learn: 0.0209596	total: 40.2s	remaining: 11s
# 785:	learn: 0.0209581	total: 40.3s	remaining: 11s
# 786:	learn: 0.0209563	total: 40.3s	remaining: 10.9s
# 787:	learn: 0.0209537	total: 40.4s	remaining: 10.9s
# 788:	learn: 0.0209511	total: 40.4s	remaining: 10.8s
# 789:	learn: 0.0209502	total: 40.5s	remaining: 10.8s
# 790:	learn: 0.0209488	total: 40.5s	remaining: 10.7s
# 791:	learn: 0.0209471	total: 40.6s	remaining: 10.7s
# 792:	learn: 0.0209467	total: 40.6s	remaining: 10.6s
# 793:	learn: 0.0209455	total: 40.7s	remaining: 10.5s
# 794:	learn: 0.0209446	total: 40.7s	remaining: 10.5s
# 795:	learn: 0.0209432	total: 40.7s	remaining: 10.4s
# 796:	learn: 0.0209406	total: 40.8s	remaining: 10.4s
# 797:	learn: 0.0209372	total: 40.8s	remaining: 10.3s
# 798:	learn: 0.0209357	total: 40.9s	remaining: 10.3s
# 799:	learn: 0.0209318	total: 40.9s	remaining: 10.2s
# 800:	learn: 0.0209307	total: 41s	remaining: 10.2s
# 801:	learn: 0.0209278	total: 41s	remaining: 10.1s
# 802:	learn: 0.0209261	total: 41.1s	remaining: 10.1s
# 803:	learn: 0.0209250	total: 41.1s	remaining: 10s
# 804:	learn: 0.0209246	total: 41.1s	remaining: 9.97s
# 805:	learn: 0.0209228	total: 41.2s	remaining: 9.91s
# 806:	learn: 0.0209196	total: 41.2s	remaining: 9.86s
# 807:	learn: 0.0209183	total: 41.3s	remaining: 9.81s
# 808:	learn: 0.0209176	total: 41.3s	remaining: 9.76s
# 809:	learn: 0.0209154	total: 41.4s	remaining: 9.7s
# 810:	learn: 0.0209136	total: 41.4s	remaining: 9.65s
# 811:	learn: 0.0209104	total: 41.5s	remaining: 9.6s
# 812:	learn: 0.0209088	total: 41.5s	remaining: 9.55s
# 813:	learn: 0.0209069	total: 41.6s	remaining: 9.5s
# 814:	learn: 0.0209048	total: 41.6s	remaining: 9.45s
# 815:	learn: 0.0209040	total: 41.7s	remaining: 9.39s
# 816:	learn: 0.0209023	total: 41.7s	remaining: 9.34s
# 817:	learn: 0.0209012	total: 41.8s	remaining: 9.29s
# 818:	learn: 0.0208987	total: 41.8s	remaining: 9.24s
# 819:	learn: 0.0208972	total: 41.9s	remaining: 9.19s
# 820:	learn: 0.0208965	total: 41.9s	remaining: 9.13s
# 821:	learn: 0.0208950	total: 41.9s	remaining: 9.08s
# 822:	learn: 0.0208934	total: 42s	remaining: 9.03s
# 823:	learn: 0.0208910	total: 42s	remaining: 8.97s
# 824:	learn: 0.0208894	total: 42.1s	remaining: 8.92s
# 825:	learn: 0.0208875	total: 42.1s	remaining: 8.87s
# 826:	learn: 0.0208867	total: 42.2s	remaining: 8.82s
# 827:	learn: 0.0208856	total: 42.2s	remaining: 8.77s
# 828:	learn: 0.0208837	total: 42.2s	remaining: 8.71s
# 829:	learn: 0.0208812	total: 42.3s	remaining: 8.66s
# 830:	learn: 0.0208796	total: 42.3s	remaining: 8.61s
# 831:	learn: 0.0208759	total: 42.4s	remaining: 8.56s
# 832:	learn: 0.0208741	total: 42.4s	remaining: 8.51s
# 833:	learn: 0.0208711	total: 42.5s	remaining: 8.45s
# 834:	learn: 0.0208701	total: 42.5s	remaining: 8.4s
# 835:	learn: 0.0208691	total: 42.5s	remaining: 8.34s
# 836:	learn: 0.0208684	total: 42.6s	remaining: 8.29s
# 837:	learn: 0.0208668	total: 42.7s	remaining: 8.24s
# 838:	learn: 0.0208664	total: 42.7s	remaining: 8.19s
# 839:	learn: 0.0208646	total: 42.8s	remaining: 8.14s
# 840:	learn: 0.0208618	total: 42.8s	remaining: 8.09s
# 841:	learn: 0.0208601	total: 42.8s	remaining: 8.04s
# 842:	learn: 0.0208587	total: 42.9s	remaining: 7.99s
# 985:	learn: 0.0205879	total: 51s	remaining: 724ms
# 986:	learn: 0.0205867	total: 51s	remaining: 672ms
# 987:	learn: 0.0205838	total: 51s	remaining: 620ms
# 988:	learn: 0.0205828	total: 51.1s	remaining: 568ms
# 989:	learn: 0.0205826	total: 51.1s	remaining: 517ms
# 990:	learn: 0.0205816	total: 51.2s	remaining: 465ms
# 991:	learn: 0.0205788	total: 51.2s	remaining: 413ms
# 992:	learn: 0.0205779	total: 51.3s	remaining: 362ms
# 993:	learn: 0.0205774	total: 51.3s	remaining: 310ms
# 994:	learn: 0.0205752	total: 51.4s	remaining: 258ms
# 995:	learn: 0.0205733	total: 51.4s	remaining: 207ms
# 996:	learn: 0.0205708	total: 51.5s	remaining: 155ms
# 997:	learn: 0.0205695	total: 51.5s	remaining: 103ms
# 998:	learn: 0.0205686	total: 51.6s	remaining: 51.6ms
# 999:	learn: 0.0205674	total: 51.6s	remaining: 0us

# %%
y_pred = ctb.predict(X_test_ctb)
mape = MAPE(y_test, np.exp(y_pred))
share_10 = share_within_indifference_interval(y_test, np.exp(y_pred), 10)

print('CatBoost:')
print(f'MAPE: {mape}')
print(f'Share 10%: {share_10}')
# Out:
# CatBoost:
# MAPE: 24.685501186183977
# Share 10%: 31.620724491268582

# %% [markdown]
# ### XGBoost

# %%
pipeline_xgb = Pipeline(steps=[
    ('preprocessor', column_transform),
    ('xgb', XGBRegressor())
])

# %%
pipeline_xgb.fit(X_train, np.log(y_train))
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   ['area_name', 'region_name',
#                                                    'experience',
#                                                    'employer_name', 'schedule',
#                                                    'employment', 'field',
#                                                    'role', 'grade',
#                                                    'professional_roles_name',
#                                                    'accredited_it_employer',
#                                                    'has_test', 'billing_type',
#                                                    'allow_messages',
#                                                    'accept_temporary',
#                                                    'response_l...
#                               feature_types=None, gamma=None, grow_policy=None,
#                               importance_type=None,
#                               interaction_constraints=None, learning_rate=None,
#                               max_bin=None, max_cat_threshold=None,
#                               max_cat_to_onehot=None, max_delta_step=None,
#                               max_depth=None, max_leaves=None,
#                               min_child_weight=None, missing=nan,
#                               monotone_constraints=None, multi_strategy=None,
#                               n_estimators=None, n_jobs=None,
#                               num_parallel_tree=None, random_state=None, ...))])

# %%
y_pred = pipeline_xgb.predict(X_test)
mape = MAPE(y_test, np.exp(y_pred))
share_10 = share_within_indifference_interval(y_test, np.exp(y_pred), 10)

print('XGBoost:')
print(f'MAPE: {mape}')
print(f'Share 10%: {share_10}')
# Out:
# XGBoost:
# MAPE: 26.26382450013334
# Share 10%: 28.258045894068406
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0, 3, 6, 7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

pipeline_rfr = Pipeline(steps=[
    ('preprocessor', column_transform),
    ('rfr', RandomForestRegressor())
])

# %%
pipeline_rfr.fit(X_train, np.log(y_train))
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   ['area_name', 'region_name',
#                                                    'experience',
#                                                    'employer_name', 'schedule',
#                                                    'employment', 'field',
#                                                    'role', 'grade',
#                                                    'professional_roles_name',
#                                                    'accredited_it_employer',
#                                                    'has_test', 'billing_type',
#                                                    'allow_messages',
#                                                    'accept_temporary',
#                                                    'response_letter_required',
#                                                    'accept_incomplete_resumes']),
#                                                  ('num', StandardScaler(),
#                                                   ['count_key_skills']),
#                                                  ('name',
#                                                   CountVectorizer(max_features=20),
#                                                   'name'),
#                                                  ('key_skills',
#                                                   CountVectorizer(max_features=20),
#                                                   'key_skills')])),
#                 ('rfr', RandomForestRegressor())])

# %%
y_pred = pipeline_rfr.predict(X_test)
mape = MAPE(y_test, np.exp(y_pred))
share_10 = share_within_indifference_interval(y_test, np.exp(y_pred), 10)

print('Random Forest:')
print(f'MAPE: {mape}')
print(f'Share 10%: {share_10}')
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:241: UserWarning: Found unknown categories in columns [0, 3, 6, 7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# Random Forest:
# MAPE: 24.45430669427721
# Share 10%: 34.564872275941696

# %% [markdown]
# ### SVM

# %%
from sklearn.svm import LinearSVR

pipeline_svm = Pipeline(steps=[
    ('preprocessor', column_transform),
    ('rfr', LinearSVR())
])

# %%
pipeline_svm.fit(X_train, np.log(y_train))
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   ['area_name', 'region_name',
#                                                    'experience',
#                                                    'employer_name', 'schedule',
#                                                    'employment', 'field',
#                                                    'role', 'grade',
#                                                    'professional_roles_name',
#                                                    'accredited_it_employer',
#                                                    'has_test', 'billing_type',
#                                                    'allow_messages',
#                                                    'accept_temporary',
#                                                    'response_letter_required',
#                                                    'accept_incomplete_resumes']),
#                                                  ('num', StandardScaler(),
#                                                   ['count_key_skills']),
#                                                  ('name',
#                                                   CountVectorizer(max_features=20),
#                                                   'name'),
#                                                  ('key_skills',
#                                                   CountVectorizer(max_features=20),
#                                                   'key_skills')])),
#                 ('rfr', LinearSVR())])

# %%
y_pred = pipeline_svm.predict(X_test)
mape = MAPE(y_test, np.exp(y_pred))
share_10 = share_within_indifference_interval(y_test, np.exp(y_pred), 10)

print('SVM:')
print(f'MAPE: {mape}')
print(f'Share 10%: {share_10}')
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:241: UserWarning: Found unknown categories in columns [0, 3, 6, 7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# SVM:
# MAPE: 25.50792752227331
# Share 10%: 32.08255159474672

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsRegressor

pipeline_knn = Pipeline(steps=[
    ('preprocessor', column_transform),
    ('rfr', KNeighborsRegressor())
])

# %%
pipeline_knn.fit(X_train, np.log(y_train))
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   ['area_name', 'region_name',
#                                                    'experience',
#                                                    'employer_name', 'schedule',
#                                                    'employment', 'field',
#                                                    'role', 'grade',
#                                                    'professional_roles_name',
#                                                    'accredited_it_employer',
#                                                    'has_test', 'billing_type',
#                                                    'allow_messages',
#                                                    'accept_temporary',
#                                                    'response_letter_required',
#                                                    'accept_incomplete_resumes']),
#                                                  ('num', StandardScaler(),
#                                                   ['count_key_skills']),
#                                                  ('name',
#                                                   CountVectorizer(max_features=20),
#                                                   'name'),
#                                                  ('key_skills',
#                                                   CountVectorizer(max_features=20),
#                                                   'key_skills')])),
#                 ('rfr', KNeighborsRegressor())])

# %%
y_pred = pipeline_knn.predict(X_test)
mape = MAPE(y_test, np.exp(y_pred))
share_10 = share_within_indifference_interval(y_test, np.exp(y_pred), 10)

print('KNN:')
print(f'MAPE: {mape}')
print(f'Share 10%: {share_10}')
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:241: UserWarning: Found unknown categories in columns [0, 3, 6, 7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# KNN:
# MAPE: 31.95118912238638
# Share 10%: 28.488959445807478

# %% [markdown]
# ### Выводы
# - В ходе экспериментов были протестированы модели градиентного бустинга (Catboost и XGBoost), случайного леса, SVM и KNN с дефолтными гиперпараметрами
# - Лучший результат по обеим метрикам на тестовой выборке показала модель случайного леса (MAPE - 24.45 %, Доля вакансий с ошибкой в пределах 10 % - 34.56 %)
